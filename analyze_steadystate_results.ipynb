# %% [markdown]
# # RNN Transfer Demonstration with Steady States
#
# The goal of this notebook is to analyze time-rescaling of a pre-trained RNN when predicting constant data. When the RNN is "well behaved" and approaches an equilibrium at some characteristic rate, scaling the bias terms of the forget and input gate can change the rate at which the system equilibrates
#
# The RNN was pre-trained on 10h FMC sensors, with atmospheric inputs standard scaled. 100 replications of the RNN varied train/val split and initial weights.
#
# The replications are analyzed to see if they exhibit steady-state behavior and if time-warp is consistent with changing a characteristic rate

# %% [markdown]
# ## Setup

# %%
import numpy as np
import h5py
import os
import os.path as osp
import tensorflow as tf
import pandas as pd
import joblib
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
from src.models import moisture_rnn as mrnn
from src.utils import read_yml, time_intp, plot_styles

# %%
# Read Trained model
params = read_yml("models/params.yaml")
rnn = mrnn.RNN_Flexible(params=params)
scaler = joblib.load("models/scaler.joblib")

# %%
rnn.load_weights('models/rnn.keras')

# %%
ml_data = pd.read_pickle("models/ml_data.pkl")

# %%
results = pd.read_pickle("outputs/steady_reps/results_reps.pkl")

# %%
nsteps=168
spinup=12

# %%
# document-safe plot defaults
DPI = 300
LABEL_SIZE = 14
TICK_SIZE = 12
CBAR_LABEL_SIZE = 13

# %% [markdown]
# ### Constant Mean Case

# %% [markdown]
# ### Real Observation Cases

# %%
# Station in Rocky Mountain Arsenal
st1 = "AENC2"
dat1 = ml_data[st1]["data"].iloc[-1] # Last available time
print(f"Station: {st1}")
print(f"Time (UTC): {ml_data[st1]['times'][-1]}")
print(dat1[params["features_list"]])

# %%
# Station SW of denver
dat2 = ml_data[st1]["data"].iloc[-nsteps:]

# %% [markdown]
# ## Constant Mean - Equilibrium Behavior

# %% [markdown]
# ### Viz

# %%
pstyle = plot_styles["model"] # 10h plotting colors, since these weights are un-warped
pstyle["label"] = "Mean RNN Prediction"

# %%
base_mean_case = np.stack([results[seed]["base"]["p0"] for seed in results], axis=0)

spinup = 12

Y = base_mean_case[:, spinup:]   # (nreps, timesteps_after_spinup)
t = np.arange(Y.shape[1])

# Mean and +- 1 std across seeds at each timestep
mean_curve = np.mean(Y, axis=0)
std_curve  = np.std(Y, axis=0)

lower = mean_curve - std_curve
upper = mean_curve + std_curve

fig, ax = plt.subplots(dpi=DPI, figsize=(10,6))

ax.plot(t, mean_curve, linewidth=3, **pstyle)

ax.fill_between(
    t,
    lower,
    upper,
    alpha=0.3,
    color=pstyle["color"],
    label=r"$\pm$ 1 std (across seeds)"
)

ax.set_xlabel("Timestep (Post-Spinup)", fontsize=LABEL_SIZE)
ax.set_ylabel("FM10 (%)", fontsize=LABEL_SIZE)
ax.tick_params(axis="both", labelsize=TICK_SIZE)

ax.legend(fontsize=TICK_SIZE)

plt.tight_layout()
plt.show()

# %%
eq = base_mean_case[:, -1]

mu = np.mean(eq)
sigma = np.std(eq)

fig, ax = plt.subplots(dpi=DPI)

# histogram
ax.hist(eq,
        bins=10,
        color=pstyle["color"],
        edgecolor="white",
        alpha=0.3)

# mean line
ax.axvline(mu,
           linestyle="--",
           linewidth=3,
           color=pstyle["color"],
           label="Mean")

# ±1 std lines
ax.axvline(mu + sigma,
           linestyle="--",
           linewidth=2,
           color=pstyle["color"],
           alpha=0.7,
           label=r"$\pm$1 SD")

ax.axvline(mu - sigma,
           linestyle="--",
           linewidth=2,
           color=pstyle["color"],
           alpha=0.7)

ax.set_xlabel("Final FM10 Value (%)", fontsize=LABEL_SIZE)
ax.set_ylabel("Number of Replications", fontsize=LABEL_SIZE)

ax.tick_params(axis="both", labelsize=TICK_SIZE)

ax.legend(fontsize=TICK_SIZE)

plt.tight_layout()
plt.show()

# %%
# Tail-end behavior metrics
K = 24
spinup = 12

Y = base_mean_case[:, spinup:]
tail = Y[:, -K:]

slope_end = (tail[:, -1] - tail[:, 0]) / (K - 1)

dy = np.diff(tail, axis=1)
slope_mean = dy.mean(axis=1)
wiggle = dy.std(axis=1)

# Side-by-side histograms
fig, axes = plt.subplots(1, 2, figsize=(12, 4), dpi=DPI)

color = pstyle["color"]

# --- Histogram 1: Mean tail slope (drift) ---
axes[0].hist(slope_mean,
             bins="auto",
             color=color,
             alpha=0.4,
             edgecolor="white",
             linewidth=1.2)

axes[0].axvline(np.mean(slope_mean),
                linestyle="--",
                linewidth=2,
                color=color)

axes[0].set_title(f"Tail Mean Slope Across Seeds (Last {K} Steps)",
                  fontsize=LABEL_SIZE)

axes[0].set_xlabel("Mean ΔFMC per Timestep\n(percentage points per timestep)",
                   fontsize=LABEL_SIZE)

axes[0].set_ylabel("Number of Replications",
                   fontsize=LABEL_SIZE)

axes[0].tick_params(axis="both", labelsize=TICK_SIZE)


# --- Histogram 2: Tail wiggle (std of increments) ---
axes[1].hist(wiggle,
             bins="auto",
             color=color,
             alpha=0.4,
             edgecolor="white",
             linewidth=1.2)

axes[1].axvline(np.mean(wiggle),
                linestyle="--",
                linewidth=2,
                color=color)

axes[1].set_title(f"Tail Increment Variability Across Seeds (Last {K} Steps)",
                  fontsize=LABEL_SIZE)

axes[1].set_xlabel("Std of ΔFMC per Timestep\n(percentage points per timestep)",
                   fontsize=LABEL_SIZE)

axes[1].set_ylabel("Number of Replications",
                   fontsize=LABEL_SIZE)

axes[1].tick_params(axis="both", labelsize=TICK_SIZE)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Sine Wave Equilibrium Behavior

# %%
from src.steady_state_reps import make_sine_eq_case

# %%
xs, xs_scaled = make_sine_eq_case(scaler)

# %%
Ed_id = params["features_list"].index("Ed")
Ew_id = params["features_list"].index("Ew")

# %%
pstyle = plot_styles["model"] # 10h plotting colors, since these weights are un-warped
pstyle["label"] = "Mean RNN Prediction"

# %%
wave_mean_case = np.stack([results[seed]["base"]["ps"] for seed in results], axis=0)

spinup = 6

Y = wave_mean_case[:, spinup:]   # shape (nreps, timesteps_after_spinup)
t = np.arange(Y.shape[1])

# Mean and +- 1 std across reps at each timestep
mean_curve = np.mean(Y, axis=0)
std_curve  = np.std(Y, axis=0)

lower = mean_curve - std_curve
upper = mean_curve + std_curve

fig, ax = plt.subplots(dpi=DPI, figsize=(10, 6))

ax.plot(t, mean_curve, linewidth=3, **pstyle)

ax.plot(t, xs[spinup:,Ed_id], linewidth=3, **plot_styles["Ed"])


ax.fill_between(
    t,
    lower,
    upper,
    alpha=0.3,
    color=pstyle["color"],
    label=r"$\pm$ 1 std (across seeds)"
)

ax.set_xlabel("Timestep (Post-Spinup)", fontsize=LABEL_SIZE)
ax.set_ylabel("FM10 (%)", fontsize=LABEL_SIZE)
ax.tick_params(axis="both", labelsize=TICK_SIZE)

ax.legend(fontsize=TICK_SIZE)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Real Data Case Equilibrium Behavior

# %%
from src.steady_state_reps import make_raws_case, make_raws_constant_case

# %%
x1, x1_scaled = make_raws_constant_case(scaler, dat1, params=params)
x2, x2_scaled = make_raws_case(scaler, dat2, params=params)

# %%
plot_styles["fm"]["linestyle"] = "--"

# %%
raws1_mean_case = np.stack([results[seed]["base"]["p1"] for seed in results], axis=0)

spinup = 6

Y = raws1_mean_case[:, spinup:]   # shape (nreps, timesteps_after_spinup)
t = np.arange(Y.shape[1])

# Mean and +- 1 std across reps at each timestep
mean_curve = np.mean(Y, axis=0)
std_curve  = np.std(Y, axis=0)

lower = mean_curve - std_curve
upper = mean_curve + std_curve

fig, ax = plt.subplots(dpi=DPI, figsize=(10, 6))

ax.plot(t, mean_curve, linewidth=3, **pstyle)
ax.plot(t, np.repeat(dat1.fm, len(t)), linewidth=3, **plot_styles["fm"])


ax.fill_between(
    t,
    lower,
    upper,
    alpha=0.3,
    color=pstyle["color"],
    label=r"$\pm$ 1 std (across seeds)"
)

ax.set_xlabel("Timestep (Post-Spinup)", fontsize=LABEL_SIZE)
ax.set_ylabel("FM10 (%)", fontsize=LABEL_SIZE)
ax.tick_params(axis="both", labelsize=TICK_SIZE)

ax.legend(fontsize=TICK_SIZE)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Read Dynamic Inputs
#
# Used to show that the uncertainty is tighter when data inputs are representative of training set

# %%
raws2_mean_case = np.stack([results[seed]["base"]["p2"] for seed in results], axis=0)

spinup = 6

Y = raws2_mean_case[:, spinup:]   # shape (nreps, timesteps_after_spinup)
t = np.arange(Y.shape[1])

# Mean and +- 1 std across reps at each timestep
mean_curve = np.mean(Y, axis=0)
std_curve  = np.std(Y, axis=0)

lower = mean_curve - std_curve
upper = mean_curve + std_curve

fig, ax = plt.subplots(dpi=DPI, figsize=(10, 6))

ax.plot(t, mean_curve, linewidth=3, **pstyle)
ax.plot(t, dat2.fm[spinup:], linewidth=3, **plot_styles["fm"])
ax.plot(t, dat2.rain[spinup:], linewidth=3, **plot_styles["rain"])


ax.fill_between(
    t,
    lower,
    upper,
    alpha=0.3,
    color=pstyle["color"],
    label=r"$\pm$ 1 std (across seeds)"
)

ax.set_xlabel("Timestep (Post-Spinup)", fontsize=LABEL_SIZE)
ax.set_ylabel("FM10 (%)", fontsize=LABEL_SIZE)
ax.tick_params(axis="both", labelsize=TICK_SIZE)

ax.legend(fontsize=TICK_SIZE)

plt.tight_layout()
plt.show()
